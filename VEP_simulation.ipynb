# %%
# %matplotlib inline
import matplotlib.colors as colors

# Import tvb library.
import tvb.simulator.lab as tvb
from tvb.basic.neotraits.api import Final, List
from tvb.simulator.lab import *
from tvb.datatypes import graph
from tvb.datatypes.time_series import TimeSeriesRegion 
from tvb.analyzers.info import sampen
import tvb.simulator.plot.power_spectra_interactive as ps_int
import random 

# Import a bunch of stuff to ease command line usage.
from scipy.stats import entropy, chi2_contingency, circvar, pearsonr, ttest_ind
from scipy import signal
from scipy.signal import butter, lfilter, freqz, hilbert, coherence, filtfilt
from scipy.special import xlogy
import matplotlib.pyplot as plt
import numpy as np
import time as tm
import statistics
import pandas as pd
import seaborn as sns
import scipy.integrate as spi
from mpl_toolkits.mplot3d import Axes3D

import tvb.datatypes.projections as projections

# %%
def myfunct_CTR(chan,amplitude,tau):
    
    con =  connectivity.Connectivity.from_file('connectivity_76.zip')

    con.weights[21] = con.weights[21] - np.ones((76)) * weightval
    con.weights[22] = con.weights[22] - np.ones((76)) * weightval   
    con.weights[30] = con.weights[30] - np.ones((76)) * weightval
    con.weights[31] = con.weights[31] - np.ones((76)) * weightval
    con.weights[32] = con.weights[32] - np.ones((76)) * weightval
    con.weights[34] = con.weights[34] - np.ones((76)) * weightval
    con.weights[59] = con.weights[59] - np.ones((76)) * weightval
    con.weights[60] = con.weights[60] - np.ones((76)) * weightval
    con.weights[68] = con.weights[68] - np.ones((76)) * weightval
    con.weights[69] = con.weights[69] - np.ones((76)) * weightval
    con.weights[70] = con.weights[70] - np.ones((76)) * weightval 
    con.weights[72] = con.weights[72] - np.ones((76)) * weightval

    '''con.weights[71] = con.weights[71] - np.ones((76)) * weightval/2
    con.weights[29] = con.weights[29] - np.ones((76)) * weightval/2
    con.weights[28] = con.weights[28] - np.ones((76)) * weightval/2'''



    #And columns:
    con.weights[:,21] = con.weights[:,21] - np.ones((76)) * weightval
    con.weights[:,22] = con.weights[:,22] - np.ones((76)) * weightval
    con.weights[:,30] = con.weights[:,30] - np.ones((76)) * weightval
    con.weights[:,31] = con.weights[:,31] - np.ones((76)) * weightval
    con.weights[:,32] = con.weights[:,32] - np.ones((76)) * weightval
    con.weights[:,34] = con.weights[:,34] - np.ones((76)) * weightval
    con.weights[:,59] = con.weights[:,59] - np.ones((76)) * weightval
    con.weights[:,60] = con.weights[:,60] - np.ones((76)) * weightval
    con.weights[:,68] = con.weights[:,68] - np.ones((76)) * weightval
    con.weights[:,69] = con.weights[:,69] - np.ones((76)) * weightval
    con.weights[:,70] = con.weights[:,70] - np.ones((76)) * weightval
    con.weights[:,72] = con.weights[:,72] - np.ones((76)) * weightval

    '''con.weights[:,71] = con.weights[:,71] - np.ones((76)) * weightval/2
    con.weights[:,29] = con.weights[:,29] - np.ones((76)) * weightval/2
    con.weights[:,28] = con.weights[:,28] - np.ones((76)) * weightval/2'''


    #Adjusting single elements:
    #weightval = 2.5

    #self
    con.weights[21][21] += (2*weightval)
    con.weights[22][22] += (2*weightval)
    con.weights[30][30] += (2*weightval)
    con.weights[31][31] += (2*weightval)
    con.weights[32][32] += (2*weightval)
    con.weights[34][34] += (2*weightval)
    con.weights[59][59] += (2*weightval)
    con.weights[60][60] += (2*weightval)
    con.weights[68][68] += (2*weightval)
    con.weights[69][69] += (2*weightval)
    con.weights[70][70] += (2*weightval)
    con.weights[72][72] += (2*weightval)

    #cross left hemisphere
    con.weights[21][34] += (2*weightval)
    con.weights[21][33] += (2*weightval)
    con.weights[21][16] += (2*weightval)
    con.weights[34][33] += (2*weightval)
    con.weights[34][6]  += (2*weightval)
    con.weights[34][8]  += (2*weightval)
    con.weights[34][16] += (2*weightval)
    con.weights[22][24] += (2*weightval)
    con.weights[22][26] += (2*weightval)
    con.weights[30][9]  += (2*weightval)
    con.weights[30][17] += (2*weightval)
    con.weights[30][27] += (2*weightval)
    con.weights[30][17] += (2*weightval)
    con.weights[31][8]  += (2*weightval)
    con.weights[31][10] += (2*weightval)
    con.weights[31][11] += (2*weightval)
    con.weights[32][9]  += (2*weightval)
    con.weights[32][29] += (2*weightval)

    con.weights[34][21] += (2*weightval)
    con.weights[31][21] += (2*weightval)
    con.weights[16][21] += (2*weightval)
    con.weights[33][34] += (2*weightval)
    con.weights[6][34]  += (2*weightval)
    con.weights[8][34]  += (2*weightval)
    con.weights[16][34] += (2*weightval)
    con.weights[24][22] += (2*weightval)
    con.weights[26][22] += (2*weightval)
    con.weights[9][30]  += (2*weightval)
    con.weights[17][30] += (2*weightval)
    con.weights[27][30] += (2*weightval)
    con.weights[17][30] += (2*weightval)
    con.weights[8][31]  += (2*weightval)
    con.weights[10][31] += (2*weightval)
    con.weights[11][31] += (2*weightval)
    con.weights[9][32]  += (2*weightval)
    con.weights[29][32] += (2*weightval)

    #cross right hemisphere
    con.weights[59][44] += (2*weightval)
    con.weights[59][46] += (2*weightval)
    con.weights[59][48] += (2*weightval)
    con.weights[59][58] += (2*weightval)
    con.weights[59][44] += (2*weightval)
    con.weights[59][70] += (2*weightval)
    con.weights[60][58] += (2*weightval)
    con.weights[68][39] += (2*weightval)
    con.weights[68][47] += (2*weightval)
    con.weights[68][49] += (2*weightval)
    con.weights[68][69] += (2*weightval)
    con.weights[68][71] += (2*weightval)
    con.weights[68][72] += (2*weightval)
    con.weights[69][47] += (2*weightval)
    con.weights[69][62] += (2*weightval)
    con.weights[69][74] += (2*weightval)
    con.weights[70][40] += (2*weightval)
    con.weights[70][46] += (2*weightval)
    con.weights[70][48] += (2*weightval)
    con.weights[70][49] += (2*weightval)
    con.weights[72][47] += (2*weightval)
    con.weights[72][74] += (2*weightval)

    con.weights[44][59] += (2*weightval)
    con.weights[46][59] += (2*weightval)
    con.weights[48][59] += (2*weightval)
    con.weights[58][59] += (2*weightval)
    con.weights[44][59] += (2*weightval)
    con.weights[70][59] += (2*weightval)
    con.weights[58][60] += (2*weightval)
    con.weights[39][68] += (2*weightval)
    con.weights[47][68] += (2*weightval)
    con.weights[49][68] += (2*weightval)
    con.weights[69][68] += (2*weightval)
    con.weights[71][68] += (2*weightval)
    con.weights[72][68] += (2*weightval)
    con.weights[47][69] += (2*weightval)
    con.weights[62][69] += (2*weightval)
    con.weights[74][69] += (2*weightval)
    con.weights[40][70] += (2*weightval)
    con.weights[46][70] += (2*weightval)
    con.weights[48][70] += (2*weightval)
    con.weights[49][70] += (2*weightval)
    con.weights[47][72] += (2*weightval)
    con.weights[74][72] += (2*weightval)

    #adjust the tract lenghts between nodes in rows:
    con.tract_lengths[21,:] = con.tract_lengths[21,:]*1.2
    con.tract_lengths[22,:] = con.tract_lengths[22,:]*1.2
    con.tract_lengths[30,:] = con.tract_lengths[30,:]*1.2
    con.tract_lengths[31,:] = con.tract_lengths[31,:]*1.2
    con.tract_lengths[32,:] = con.tract_lengths[32,:]*1.2
    con.tract_lengths[34,:] = con.tract_lengths[34,:]*1.2
    con.tract_lengths[59,:] = con.tract_lengths[59,:]*1.2
    con.tract_lengths[60,:] = con.tract_lengths[60,:]*1.2
    con.tract_lengths[68,:] = con.tract_lengths[68,:]*1.2
    con.tract_lengths[69,:] = con.tract_lengths[69,:]*1.2
    con.tract_lengths[70,:] = con.tract_lengths[70,:]*1.2
    con.tract_lengths[72,:] = con.tract_lengths[72,:]*1.2

    #And columns
    con.tract_lengths[:,21] = con.tract_lengths[:,21]*1.2
    con.tract_lengths[:,22] = con.tract_lengths[:,22]*1.2
    con.tract_lengths[:,30] = con.tract_lengths[:,30]*1.2
    con.tract_lengths[:,31] = con.tract_lengths[:,31]*1.2
    con.tract_lengths[:,32] = con.tract_lengths[:,32]*1.2
    con.tract_lengths[:,34] = con.tract_lengths[:,34]*1.2
    con.tract_lengths[:,59] = con.tract_lengths[:,59]*1.2
    con.tract_lengths[:,60] = con.tract_lengths[:,60]*1.2
    con.tract_lengths[:,68] = con.tract_lengths[:,68]*1.2
    con.tract_lengths[:,69] = con.tract_lengths[:,69]*1.2
    con.tract_lengths[:,70] = con.tract_lengths[:,70]*1.2
    con.tract_lengths[:,72] = con.tract_lengths[:,72]*1.2




    con.weights = con.weights / np.max(con.weights)              #normalised by maximum weight  
    con.speed = np.array([np.inf])                               #no time delays => velocity ->∞
    con.configure()


    b = np.ones(76)*0.048
    b [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]]  = np.ones((12)) * bval

    B = np.ones(76)*22
    B [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]]  = np.ones((12)) * 20

    J = np.ones(76)*135
    J [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]]  = np.ones((12)) * 135

    a_4 = np.ones(76)*0.25
    a_4 [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]] = np.ones((12))*23

    a_3 = np.ones(76)*0.25
    a_3 [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]] = np.ones((12))*22

    # setup model based on paper's parameters
    model_pars = dict(
        A= 3.25,#3.25, # increased in respect to the healthy case
        B=B,
        v0=6.0,
        a=aval, # increased in respect to the healthy case. (also remember that TVB uses ms, not s)
        b=bval,
        r=0.56,
        nu_max=0.0025, # e0 in the JR original paper
        # TVB factors C_i into J*a_i, e.g. C1 = a_1 * J
        J=135,
        a_1=1.0,
        a_2=0.8,
        a_3= 0.25, #0.25,
        a_4= 0.25, #0.25,
        mu=0.22, # avg of 120 and 320 pulses/s
    )

    # implement JR + afferent PSP
    class JRPSP(tvb.models.JansenRit):
        state_variable_range = Final(
            default={"y0": np.array([-1.0, 1.0]),
                     "y1": np.array([-500.0, 500.0]),
                     "y2": np.array([-50.0, 50.0]),
                     "y3": np.array([-6.0, 6.0]),
                     "y4": np.array([-20.0, 20.0]),
                     "y5": np.array([-500.0, 500.0]),
                     "y6": np.array([-20.0, 20.0]),
                     "y7": np.array([-500.0, 500.0])})

        variables_of_interest = List(
            of=str,
            label="Variables watched by Monitors",
            choices=("y0", "y1", "y2", "y3", "y4", "y5", "y6", "y7"),
            default=("y0", "y1", "y2", "y3"))

        state_variables = tuple('y0 y1 y2 y3 y4 y5 y6 y7'.split())
        _nvar = 8
        cvar = np.array([6], dtype=np.int32)

        def dfun(self, state_variables, coupling, local_coupling=0.0):
            dy = np.zeros((8, state_variables.shape[1], 1))
            # TVB's JR is eq 6 only
            dy[:6] = super().dfun(state_variables[:6], coupling, local_coupling)
            # tack on PSP for efferent following eq 8
            # NB with this, only y12 is coupling var for TVB
            y0, y1, y2, y3, y4, y5, y6, y7 = state_variables
            a_d = self.a / 3.0
            sigm_y1_y2 = 2.0 * self.nu_max / (1.0 + np.exp(self.r * (self.v0 - (y1 - y2))))
            dy[6] = y7
            dy[7] = self.A * a_d * sigm_y1_y2 - 2.0 * a_d * y7 - self.a**2 * y6
            return dy

    # factor out noise from dy4 = A a (p(t) + ...) as y4 += dt (...) + A a dW_t
    # this allows us to model the noise as TVB does it, though scaling requires experiment

    noise_seed= random.randint(1,10)#10
    nsig = np.zeros((8, 76, 1))
    nsig[4] = model_pars['A'] * model_pars['a'] * (.320 - .120) * 5e-3
    noise = tvb.noise.Additive(nsig=nsig,noise_seed=noise_seed) #



    rm = region_mapping.RegionMapping.from_file()

    #Initialise some Monitors with period in physical time
    mon_tavg = monitors.TemporalAverage(period=1.)
    mon_EEG = monitors.EEG.from_file()
    mon_EEG.region_mapping=rm
    mon_EEG.period=1. 

    what_to_watch = (mon_tavg, mon_EEG)


    nodes = [35, 36, 73,74] 
    stim_weights = np.zeros((con.number_of_regions, 1))
    stim_weights[nodes] = np.array([3.5,0.0,3.5,0.0])[:, np.newaxis]
    eqn_t = equations.PulseTrain()
    eqn_t.parameters["onset"] = 500.0 # ms
    eqn_t.parameters["tau"]   = tau  # ms
    eqn_t.parameters["T"]     = 1500  # 0.002kHz repetition frequency
    eqn_t.parameters["amp"]   = amplitude

    stimulus = patterns.StimuliRegion(temporal = eqn_t,
                                      connectivity = con, 
                                      weight = stim_weights)


    # Initialise the Simulator.
    sim = simulator.Simulator(connectivity=con,
                              conduction_speed=np.float(con.speed),
                              model=JRPSP(
                              variables_of_interest=("y0", "y1", "y2", "y3", "y4", "y5", "y6", "y7"),
                              **{k: np.array(v) for k, v in model_pars.items()}),
                              coupling=tvb.coupling.Linear(a=np.r_[aval*10]),
                              integrator=tvb.integrators.EulerStochastic(dt=0.1, noise=noise),
                              #coupling=coupling.SigmoidalJansenRit(a=numpy.array([10.0])),
                              #integrator=integrators.HeunStochastic(dt=2 ** -4, noise=noise.Additive(nsig=sigma)),
                              #monitors=(monitors.TemporalAverage(period=1),), #period in ms
                              monitors=what_to_watch,
                              stimulus = stimulus,
                              simulation_length=1500)
    sim.configure()

    sim_time = 1500
    (ttavg_hc, tavg_hc), (teeg_hc, eeg_hc) = sim.run(simulation_length=sim_time)


    tavg_hc_whole = tavg_hc.copy()
    eeg_hc_whole = eeg_hc.copy() 

    tavg_hc_mask = tavg_hc[1000:, :, :, :]
    eeg_hc_mask = eeg_hc[1000:, :, :, :]




    tavg_hc /= (np.max(tavg_hc,0) - np.min(tavg_hc,0 ))
    tavg_hc -= np.mean(tavg_hc, 0)
    eeg_hc /= (np.max(eeg_hc,0) - np.min(eeg_hc,0 ))
    eeg_hc -= np.mean(eeg_hc, 0)
    
    


    avg=[]
    m_eeg_hc= eeg_hc[:,0,chan,0]
    avg= m_eeg_hc.mean(1)
    #print(avg)
    
    
    mask= np.arange(550,600)
    integral= spi.simpson(np.squeeze(avg[mask]),mask)
    
    min_eeg=np.min(np.squeeze(avg[mask]))
    argmin_eeg = np.argmin(np.squeeze(avg[mask]))

    #m_eeg_hc= eeg_hc[:,0,chan,0]
    mon_EEG = monitors.EEG.from_file()

    return [round(integral, 4),avg,min_eeg,argmin_eeg,ttavg_hc,tavg_hc[:, 0,35, 0]]

# %%
def myfunct_SCD(chan,amplitude,tau):

    # Initialise the Connectivity.
    con = connectivity.Connectivity.from_file('connectivity_76.zip') 






    # Setting adjusted connectivity in rows:
    con.weights[21] = con.weights[21] - np.ones((76)) * weightval_scd
    con.weights[22] = con.weights[22] - np.ones((76)) * weightval_scd
    con.weights[30] = con.weights[30] - np.ones((76)) * weightval_scd
    con.weights[31] = con.weights[31] - np.ones((76)) * weightval_scd
    con.weights[32] = con.weights[32] - np.ones((76)) * weightval_scd
    con.weights[34] = con.weights[34] - np.ones((76)) * weightval_scd
    con.weights[59] = con.weights[59] - np.ones((76)) * weightval_scd
    con.weights[60] = con.weights[60] - np.ones((76)) * weightval_scd
    con.weights[68] = con.weights[68] - np.ones((76)) * weightval_scd
    con.weights[69] = con.weights[69] - np.ones((76)) * weightval_scd
    con.weights[70] = con.weights[70] - np.ones((76)) * weightval_scd 
    con.weights[72] = con.weights[72] - np.ones((76)) * weightval_scd

    '''con.weights[71] = con.weights[71] - np.ones((76)) * weightval_scd/2
    con.weights[29] = con.weights[29] - np.ones((76)) * weightval_scd/2
    con.weights[28] = con.weights[28] - np.ones((76)) * weightval_scd/2'''



    #And columns:
    con.weights[:,21] = con.weights[:,21] - np.ones((76)) * weightval_scd
    con.weights[:,22] = con.weights[:,22] - np.ones((76)) * weightval_scd
    con.weights[:,30] = con.weights[:,30] - np.ones((76)) * weightval_scd
    con.weights[:,31] = con.weights[:,31] - np.ones((76)) * weightval_scd
    con.weights[:,32] = con.weights[:,32] - np.ones((76)) * weightval_scd
    con.weights[:,34] = con.weights[:,34] - np.ones((76)) * weightval_scd
    con.weights[:,59] = con.weights[:,59] - np.ones((76)) * weightval_scd
    con.weights[:,60] = con.weights[:,60] - np.ones((76)) * weightval_scd
    con.weights[:,68] = con.weights[:,68] - np.ones((76)) * weightval_scd
    con.weights[:,69] = con.weights[:,69] - np.ones((76)) * weightval_scd
    con.weights[:,70] = con.weights[:,70] - np.ones((76)) * weightval_scd
    con.weights[:,72] = con.weights[:,72] - np.ones((76)) * weightval_scd

    '''con.weights[:,71] = con.weights[:,71] - np.ones((76)) * weightval_scd/2
    con.weights[:,29] = con.weights[:,29] - np.ones((76)) * weightval_scd/2
    con.weights[:,28] = con.weights[:,28] - np.ones((76)) * weightval_scd/2'''


    #Adjusting single elements:
    #weightval_scd = 1.07

    #self
    con.weights[21][21] += (2*weightval_scd)
    con.weights[22][22] += (2*weightval_scd)
    con.weights[30][30] += (2*weightval_scd)
    con.weights[31][31] += (2*weightval_scd)
    con.weights[32][32] += (2*weightval_scd)
    con.weights[34][34] += (2*weightval_scd)
    con.weights[59][59] += (2*weightval_scd)
    con.weights[60][60] += (2*weightval_scd)
    con.weights[68][68] += (2*weightval_scd)
    con.weights[69][69] += (2*weightval_scd)
    con.weights[70][70] += (2*weightval_scd)
    con.weights[72][72] += (2*weightval_scd)

    #cross left hemisphere
    con.weights[21][34] += (2*weightval_scd)
    con.weights[21][33] += (2*weightval_scd)
    con.weights[21][16] += (2*weightval_scd)
    con.weights[34][33] += (2*weightval_scd)
    con.weights[34][6]  += (2*weightval_scd)
    con.weights[34][8]  += (2*weightval_scd)
    con.weights[34][16] += (2*weightval_scd)
    con.weights[22][24] += (2*weightval_scd)
    con.weights[22][26] += (2*weightval_scd)
    con.weights[30][9]  += (2*weightval_scd)
    con.weights[30][17] += (2*weightval_scd)
    con.weights[30][27] += (2*weightval_scd)
    con.weights[30][17] += (2*weightval_scd)
    con.weights[31][8]  += (2*weightval_scd)
    con.weights[31][10] += (2*weightval_scd)
    con.weights[31][11] += (2*weightval_scd)
    con.weights[32][9]  += (2*weightval_scd)
    con.weights[32][29] += (2*weightval_scd)

    con.weights[34][21] += (2*weightval_scd)
    con.weights[31][21] += (2*weightval_scd)
    con.weights[16][21] += (2*weightval_scd)
    con.weights[33][34] += (2*weightval_scd)
    con.weights[6][34]  += (2*weightval_scd)
    con.weights[8][34]  += (2*weightval_scd)
    con.weights[16][34] += (2*weightval_scd)
    con.weights[24][22] += (2*weightval_scd)
    con.weights[26][22] += (2*weightval_scd)
    con.weights[9][30]  += (2*weightval_scd)
    con.weights[17][30] += (2*weightval_scd)
    con.weights[27][30] += (2*weightval_scd)
    con.weights[17][30] += (2*weightval_scd)
    con.weights[8][31]  += (2*weightval_scd)
    con.weights[10][31] += (2*weightval_scd)
    con.weights[11][31] += (2*weightval_scd)
    con.weights[9][32]  += (2*weightval_scd)
    con.weights[29][32] += (2*weightval_scd)

    #cross right hemisphere
    con.weights[59][44] += (2*weightval_scd)
    con.weights[59][46] += (2*weightval_scd)
    con.weights[59][48] += (2*weightval_scd)
    con.weights[59][58] += (2*weightval_scd)
    con.weights[59][44] += (2*weightval_scd)
    con.weights[59][70] += (2*weightval_scd)
    con.weights[60][58] += (2*weightval_scd)
    con.weights[68][39] += (2*weightval_scd)
    con.weights[68][47] += (2*weightval_scd)
    con.weights[68][49] += (2*weightval_scd)
    con.weights[68][69] += (2*weightval_scd)
    con.weights[68][71] += (2*weightval_scd)
    con.weights[68][72] += (2*weightval_scd)
    con.weights[69][47] += (2*weightval_scd)
    con.weights[69][62] += (2*weightval_scd)
    con.weights[69][74] += (2*weightval_scd)
    con.weights[70][40] += (2*weightval_scd)
    con.weights[70][46] += (2*weightval_scd)
    con.weights[70][48] += (2*weightval_scd)
    con.weights[70][49] += (2*weightval_scd)
    con.weights[72][47] += (2*weightval_scd)
    con.weights[72][74] += (2*weightval_scd)

    con.weights[44][59] += (2*weightval_scd)
    con.weights[46][59] += (2*weightval_scd)
    con.weights[48][59] += (2*weightval_scd)
    con.weights[58][59] += (2*weightval_scd)
    con.weights[44][59] += (2*weightval_scd)
    con.weights[70][59] += (2*weightval_scd)
    con.weights[58][60] += (2*weightval_scd)
    con.weights[39][68] += (2*weightval_scd)
    con.weights[47][68] += (2*weightval_scd)
    con.weights[49][68] += (2*weightval_scd)
    con.weights[69][68] += (2*weightval_scd)
    con.weights[71][68] += (2*weightval_scd)
    con.weights[72][68] += (2*weightval_scd)
    con.weights[47][69] += (2*weightval_scd)
    con.weights[62][69] += (2*weightval_scd)
    con.weights[74][69] += (2*weightval_scd)
    con.weights[40][70] += (2*weightval_scd)
    con.weights[46][70] += (2*weightval_scd)
    con.weights[48][70] += (2*weightval_scd)
    con.weights[49][70] += (2*weightval_scd)
    con.weights[47][72] += (2*weightval_scd)
    con.weights[74][72] += (2*weightval_scd)

    #adjust the tract lenghts between nodes in rows:
    con.tract_lengths[21,:] = con.tract_lengths[21,:]*1.2
    con.tract_lengths[22,:] = con.tract_lengths[22,:]*1.2
    con.tract_lengths[30,:] = con.tract_lengths[30,:]*1.2
    con.tract_lengths[31,:] = con.tract_lengths[31,:]*1.2
    con.tract_lengths[32,:] = con.tract_lengths[32,:]*1.2
    con.tract_lengths[34,:] = con.tract_lengths[34,:]*1.2
    con.tract_lengths[59,:] = con.tract_lengths[59,:]*1.2
    con.tract_lengths[60,:] = con.tract_lengths[60,:]*1.2
    con.tract_lengths[68,:] = con.tract_lengths[68,:]*1.2
    con.tract_lengths[69,:] = con.tract_lengths[69,:]*1.2
    con.tract_lengths[70,:] = con.tract_lengths[70,:]*1.2
    con.tract_lengths[72,:] = con.tract_lengths[72,:]*1.2

    #And columns
    con.tract_lengths[:,21] = con.tract_lengths[:,21]*1.2
    con.tract_lengths[:,22] = con.tract_lengths[:,22]*1.2
    con.tract_lengths[:,30] = con.tract_lengths[:,30]*1.2
    con.tract_lengths[:,31] = con.tract_lengths[:,31]*1.2
    con.tract_lengths[:,32] = con.tract_lengths[:,32]*1.2
    con.tract_lengths[:,34] = con.tract_lengths[:,34]*1.2
    con.tract_lengths[:,59] = con.tract_lengths[:,59]*1.2
    con.tract_lengths[:,60] = con.tract_lengths[:,60]*1.2
    con.tract_lengths[:,68] = con.tract_lengths[:,68]*1.2
    con.tract_lengths[:,69] = con.tract_lengths[:,69]*1.2
    con.tract_lengths[:,70] = con.tract_lengths[:,70]*1.2
    con.tract_lengths[:,72] = con.tract_lengths[:,72]*1.2



    np.matrix.clip(con.weights, 0, 3, out=con.weights)




    #nregions = len(con.region_labels)
    #con.weights = con.weights - con.weights * np.eye((nregions)) #remove self-connection


    con.weights = con.weights / np.max(con.weights)              #normalised by maximum weight  
    con.speed = np.array([np.inf])                               #no time delays => velocity ->∞
    con.configure()


    b = np.ones(76)*0.048
    b [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]]  = np.ones((12)) * bval_scd

    B = np.ones(76)*22
    #B [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]]  = np.ones((12)) * 20

    J = np.ones(76)*135
    J [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]]  = np.ones((12)) * 135

    a_4 = np.ones(76)*0.25
    #a_4 [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]] = np.ones((12))*23

    a_3 = np.ones(76)*0.25
    #a_3 [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]] = np.ones((12))*22

    # setup model based on paper's parameters
    model_pars = dict(
        A=3.25, # increased in respect to the healthy case
        B=B,
        v0=6.0,
        a=aval_scd, # increased in respect to the healthy case. (also remember that TVB uses ms, not s)
        b=b,
        r=0.56,
        nu_max=0.0025, # e0 in the JR original paper
        # TVB factors C_i into J*a_i, e.g. C1 = a_1 * J
        J=135,
        a_1=1.0,
        a_2=0.8,
        a_3= 0.25,
        a_4= 0.25,
        mu=0.22, # avg of 120 and 320 pulses/s
    )

    # implement JR + afferent PSP
    class JRPSP(tvb.models.JansenRit):
        state_variable_range = Final(
            default={"y0": np.array([-1.0, 1.0]),
                     "y1": np.array([-500.0, 500.0]),
                     "y2": np.array([-50.0, 50.0]),
                     "y3": np.array([-6.0, 6.0]),
                     "y4": np.array([-20.0, 20.0]),
                     "y5": np.array([-500.0, 500.0]),
                     "y6": np.array([-20.0, 20.0]),
                     "y7": np.array([-500.0, 500.0])})

        variables_of_interest = List(
            of=str,
            label="Variables watched by Monitors",
            choices=("y0", "y1", "y2", "y3", "y4", "y5", "y6", "y7"),
            default=("y0", "y1", "y2", "y3"))

        state_variables = tuple('y0 y1 y2 y3 y4 y5 y6 y7'.split())
        _nvar = 8
        cvar = np.array([6], dtype=np.int32)

        def dfun(self, state_variables, coupling, local_coupling=0.0):
            dy = np.zeros((8, state_variables.shape[1], 1))
            # TVB's JR is eq 6 only
            dy[:6] = super().dfun(state_variables[:6], coupling, local_coupling)
            # tack on PSP for efferent following eq 8
            # NB with this, only y12 is coupling var for TVB
            y0, y1, y2, y3, y4, y5, y6, y7 = state_variables
            a_d = self.a / 3.0
            sigm_y1_y2 = 2.0 * self.nu_max / (1.0 + np.exp(self.r * (self.v0 - (y1 - y2))))
            dy[6] = y7
            dy[7] = self.A * a_d * sigm_y1_y2 - 2.0 * a_d * y7 - self.a**2 * y6
            return dy

    # factor out noise from dy4 = A a (p(t) + ...) as y4 += dt (...) + A a dW_t
    # this allows us to model the noise as TVB does it, though scaling requires experiment
    noise_seed= random.randint(1,100)
    nsig = np.zeros((8, 76, 1))
    nsig[4] = model_pars['A'] * model_pars['a'] * (.320 - .120) * 5e-3
    noise = tvb.noise.Additive(nsig=nsig,noise_seed=noise_seed)#




    #setting up monitors:
    mon_tavg = monitors.TemporalAverage(period=1.)
    mon_EEG = monitors.EEG.from_file()
    mon_EEG.period=1. 


    #Bundling
    what_to_watch = (mon_tavg, mon_EEG)

    #Bundling
    what_to_watch = (mon_tavg, mon_EEG)

    nodes = [35, 36,73,74] 
    stim_weights = np.zeros((con.number_of_regions, 1))
    stim_weights[nodes] = np.array([3.5, 0.0,3.5,0.0])[:, np.newaxis]
    eqn_t = equations.PulseTrain()
    eqn_t.parameters["onset"] = 500.0 # ms
    eqn_t.parameters["tau"]   = tau  #20 ms
    eqn_t.parameters["T"]     = 1500.  # 0.002kHz repetition frequency
    eqn_t.parameters["amp"]   = amplitude


    #eqn_t1 = equations.Sinusoid()
    #eqn_t1.parameters["amp"]= 0.1

    stimulus = patterns.StimuliRegion(temporal = eqn_t,
                                      connectivity = con, 
                                      weight = stim_weights)

    sim = simulator.Simulator(connectivity=con,
                              conduction_speed=np.float(con.speed),
                              model=JRPSP(
                              variables_of_interest=("y0", "y1", "y2", "y3", "y4", "y5", "y6", "y7"),
                              **{k: np.array(v) for k, v in model_pars.items()}),
                              coupling=tvb.coupling.Linear(a=np.r_[aval_scd*10]),
                              integrator=tvb.integrators.EulerStochastic(dt=0.1, noise=noise),
                              #coupling=coupling.SigmoidalJansenRit(a=numpy.array([10.0])),
                              #integrator=integrators.HeunStochastic(dt=2 ** -4, noise=noise.Additive(nsig=sigma)),
                              #monitors=(monitors.TemporalAverage(period=1),), #period in ms
                              monitors=what_to_watch,
                              stimulus = stimulus,
                              simulation_length=1500)
    sim.configure()

    sim_time = 1500
    (ttavg_scd, tavg_scd), (teeg_scd, eeg_scd) = sim.run(simulation_length=sim_time)


    tavg_scd_whole = tavg_scd.copy()
    eeg_scd_whole = eeg_scd.copy() 

    tavg_scd_mask = tavg_scd[1000:, :, :, :]
    eeg_scd_mask = eeg_scd[1000:, :, :, :]




    tavg_scd /= (np.max(tavg_scd,0) - np.min(tavg_scd,0 ))
    tavg_scd -= np.mean(tavg_scd, 0)
    eeg_scd /= (np.max(eeg_scd,0) - np.min(eeg_scd,0 ))
    eeg_scd -= np.mean(eeg_scd, 0)




    avg =[]
    m_eeg_scd=eeg_scd[:,0,chan,0]
    avg= m_eeg_scd.mean(1)
    #print(avg)
    
    mask= np.arange(550,600)
    integral= spi.simpson(np.squeeze(avg[mask]),mask)
    
    min_eeg=np.min(np.squeeze(avg[mask]))
    argmin_eeg = np.argmin(np.squeeze(avg[mask]))

    #m_eeg_hc= eeg_hc[:,0,chan,0]
    mon_EEG = monitors.EEG.from_file()

    return [round(integral, 4),avg,min_eeg,argmin_eeg,ttavg_scd,tavg_scd[:, 0,35, 0]]

# %%
def myfunct_MCI(chan,amplitude,tau):
    

    # Initialise the Connectivity.
    con = connectivity.Connectivity.from_file('connectivity_76.zip') 






    # Setting adjusted connectivity in rows:
    con.weights[21] = con.weights[21] - np.ones((76)) * weightval_mci
    con.weights[22] = con.weights[22] - np.ones((76)) * weightval_mci
    con.weights[30] = con.weights[30] - np.ones((76)) * weightval_mci
    con.weights[31] = con.weights[31] - np.ones((76)) * weightval_mci
    con.weights[32] = con.weights[32] - np.ones((76)) * weightval_mci
    con.weights[34] = con.weights[34] - np.ones((76)) * weightval_mci
    con.weights[59] = con.weights[59] - np.ones((76)) * weightval_mci
    con.weights[60] = con.weights[60] - np.ones((76)) * weightval_mci
    con.weights[68] = con.weights[68] - np.ones((76)) * weightval_mci
    con.weights[69] = con.weights[69] - np.ones((76)) * weightval_mci
    con.weights[70] = con.weights[70] - np.ones((76)) * weightval_mci 
    con.weights[72] = con.weights[72] - np.ones((76)) * weightval_mci

    '''con.weights[71] = con.weights[71] - np.ones((76)) * weightval_mci/2
    con.weights[29] = con.weights[29] - np.ones((76)) * weightval_mci/2
    con.weights[28] = con.weights[28] - np.ones((76)) * weightval_mci/2'''



    #And columns:
    con.weights[:,21] = con.weights[:,21] - np.ones((76)) * weightval_mci
    con.weights[:,22] = con.weights[:,22] - np.ones((76)) * weightval_mci
    con.weights[:,30] = con.weights[:,30] - np.ones((76)) * weightval_mci
    con.weights[:,31] = con.weights[:,31] - np.ones((76)) * weightval_mci
    con.weights[:,32] = con.weights[:,32] - np.ones((76)) * weightval_mci
    con.weights[:,34] = con.weights[:,34] - np.ones((76)) * weightval_mci
    con.weights[:,59] = con.weights[:,59] - np.ones((76)) * weightval_mci
    con.weights[:,60] = con.weights[:,60] - np.ones((76)) * weightval_mci
    con.weights[:,68] = con.weights[:,68] - np.ones((76)) * weightval_mci
    con.weights[:,69] = con.weights[:,69] - np.ones((76)) * weightval_mci
    con.weights[:,70] = con.weights[:,70] - np.ones((76)) * weightval_mci
    con.weights[:,72] = con.weights[:,72] - np.ones((76)) * weightval_mci

    '''con.weights[:,71] = con.weights[:,71] - np.ones((76)) * weightval_mci/2
    con.weights[:,29] = con.weights[:,29] - np.ones((76)) * weightval_mci/2
    con.weights[:,28] = con.weights[:,28] - np.ones((76)) * weightval_mci/2'''


    #Adjusting single elements:
    #weightval_mci = 1.07

    #self
    con.weights[21][21] += (2*weightval_mci)
    con.weights[22][22] += (2*weightval_mci)
    con.weights[30][30] += (2*weightval_mci)
    con.weights[31][31] += (2*weightval_mci)
    con.weights[32][32] += (2*weightval_mci)
    con.weights[34][34] += (2*weightval_mci)
    con.weights[59][59] += (2*weightval_mci)
    con.weights[60][60] += (2*weightval_mci)
    con.weights[68][68] += (2*weightval_mci)
    con.weights[69][69] += (2*weightval_mci)
    con.weights[70][70] += (2*weightval_mci)
    con.weights[72][72] += (2*weightval_mci)

    #cross left hemisphere
    con.weights[21][34] += (2*weightval_mci)
    con.weights[21][33] += (2*weightval_mci)
    con.weights[21][16] += (2*weightval_mci)
    con.weights[34][33] += (2*weightval_mci)
    con.weights[34][6]  += (2*weightval_mci)
    con.weights[34][8]  += (2*weightval_mci)
    con.weights[34][16] += (2*weightval_mci)
    con.weights[22][24] += (2*weightval_mci)
    con.weights[22][26] += (2*weightval_mci)
    con.weights[30][9]  += (2*weightval_mci)
    con.weights[30][17] += (2*weightval_mci)
    con.weights[30][27] += (2*weightval_mci)
    con.weights[30][17] += (2*weightval_mci)
    con.weights[31][8]  += (2*weightval_mci)
    con.weights[31][10] += (2*weightval_mci)
    con.weights[31][11] += (2*weightval_mci)
    con.weights[32][9]  += (2*weightval_mci)
    con.weights[32][29] += (2*weightval_mci)

    con.weights[34][21] += (2*weightval_mci)
    con.weights[31][21] += (2*weightval_mci)
    con.weights[16][21] += (2*weightval_mci)
    con.weights[33][34] += (2*weightval_mci)
    con.weights[6][34]  += (2*weightval_mci)
    con.weights[8][34]  += (2*weightval_mci)
    con.weights[16][34] += (2*weightval_mci)
    con.weights[24][22] += (2*weightval_mci)
    con.weights[26][22] += (2*weightval_mci)
    con.weights[9][30]  += (2*weightval_mci)
    con.weights[17][30] += (2*weightval_mci)
    con.weights[27][30] += (2*weightval_mci)
    con.weights[17][30] += (2*weightval_mci)
    con.weights[8][31]  += (2*weightval_mci)
    con.weights[10][31] += (2*weightval_mci)
    con.weights[11][31] += (2*weightval_mci)
    con.weights[9][32]  += (2*weightval_mci)
    con.weights[29][32] += (2*weightval_mci)

    #cross right hemisphere
    con.weights[59][44] += (2*weightval_mci)
    con.weights[59][46] += (2*weightval_mci)
    con.weights[59][48] += (2*weightval_mci)
    con.weights[59][58] += (2*weightval_mci)
    con.weights[59][44] += (2*weightval_mci)
    con.weights[59][70] += (2*weightval_mci)
    con.weights[60][58] += (2*weightval_mci)
    con.weights[68][39] += (2*weightval_mci)
    con.weights[68][47] += (2*weightval_mci)
    con.weights[68][49] += (2*weightval_mci)
    con.weights[68][69] += (2*weightval_mci)
    con.weights[68][71] += (2*weightval_mci)
    con.weights[68][72] += (2*weightval_mci)
    con.weights[69][47] += (2*weightval_mci)
    con.weights[69][62] += (2*weightval_mci)
    con.weights[69][74] += (2*weightval_mci)
    con.weights[70][40] += (2*weightval_mci)
    con.weights[70][46] += (2*weightval_mci)
    con.weights[70][48] += (2*weightval_mci)
    con.weights[70][49] += (2*weightval_mci)
    con.weights[72][47] += (2*weightval_mci)
    con.weights[72][74] += (2*weightval_mci)

    con.weights[44][59] += (2*weightval_mci)
    con.weights[46][59] += (2*weightval_mci)
    con.weights[48][59] += (2*weightval_mci)
    con.weights[58][59] += (2*weightval_mci)
    con.weights[44][59] += (2*weightval_mci)
    con.weights[70][59] += (2*weightval_mci)
    con.weights[58][60] += (2*weightval_mci)
    con.weights[39][68] += (2*weightval_mci)
    con.weights[47][68] += (2*weightval_mci)
    con.weights[49][68] += (2*weightval_mci)
    con.weights[69][68] += (2*weightval_mci)
    con.weights[71][68] += (2*weightval_mci)
    con.weights[72][68] += (2*weightval_mci)
    con.weights[47][69] += (2*weightval_mci)
    con.weights[62][69] += (2*weightval_mci)
    con.weights[74][69] += (2*weightval_mci)
    con.weights[40][70] += (2*weightval_mci)
    con.weights[46][70] += (2*weightval_mci)
    con.weights[48][70] += (2*weightval_mci)
    con.weights[49][70] += (2*weightval_mci)
    con.weights[47][72] += (2*weightval_mci)
    con.weights[74][72] += (2*weightval_mci)

    #adjust the tract lenghts between nodes in rows:
    con.tract_lengths[21,:] = con.tract_lengths[21,:]*1.2
    con.tract_lengths[22,:] = con.tract_lengths[22,:]*1.2
    con.tract_lengths[30,:] = con.tract_lengths[30,:]*1.2
    con.tract_lengths[31,:] = con.tract_lengths[31,:]*1.2
    con.tract_lengths[32,:] = con.tract_lengths[32,:]*1.2
    con.tract_lengths[34,:] = con.tract_lengths[34,:]*1.2
    con.tract_lengths[59,:] = con.tract_lengths[59,:]*1.2
    con.tract_lengths[60,:] = con.tract_lengths[60,:]*1.2
    con.tract_lengths[68,:] = con.tract_lengths[68,:]*1.2
    con.tract_lengths[69,:] = con.tract_lengths[69,:]*1.2
    con.tract_lengths[70,:] = con.tract_lengths[70,:]*1.2
    con.tract_lengths[72,:] = con.tract_lengths[72,:]*1.2

    #And columns
    con.tract_lengths[:,21] = con.tract_lengths[:,21]*1.2
    con.tract_lengths[:,22] = con.tract_lengths[:,22]*1.2
    con.tract_lengths[:,30] = con.tract_lengths[:,30]*1.2
    con.tract_lengths[:,31] = con.tract_lengths[:,31]*1.2
    con.tract_lengths[:,32] = con.tract_lengths[:,32]*1.2
    con.tract_lengths[:,34] = con.tract_lengths[:,34]*1.2
    con.tract_lengths[:,59] = con.tract_lengths[:,59]*1.2
    con.tract_lengths[:,60] = con.tract_lengths[:,60]*1.2
    con.tract_lengths[:,68] = con.tract_lengths[:,68]*1.2
    con.tract_lengths[:,69] = con.tract_lengths[:,69]*1.2
    con.tract_lengths[:,70] = con.tract_lengths[:,70]*1.2
    con.tract_lengths[:,72] = con.tract_lengths[:,72]*1.2



    np.matrix.clip(con.weights, 0, 3, out=con.weights)




    #nregions = len(con.region_labels)
    #con.weights = con.weights - con.weights * np.eye((nregions)) #remove self-connection
    con.weights = con.weights / np.max(con.weights)              #normalised by maximum weight  
    con.speed = np.array([np.inf])                               #no time delays => velocity ->∞
    con.configure()


    b = np.ones(76)*0.048
    b [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]]  = np.ones((12)) * bval_mci

    B = np.ones(76)*22
    #B [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]]  = np.ones((12)) * 20

    J = np.ones(76)*135
    J [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]]  = np.ones((12)) * 135

    a_4 = np.ones(76)*0.25
    #a_4 [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]] = np.ones((12))*23

    a_3 = np.ones(76)*0.25
    #a_3 [[21, 22, 30, 31, 32, 34, 59, 60, 68, 69, 70, 72]] = np.ones((12))*22

    # setup model based on paper's parameters
    model_pars = dict(
        A=3.25, # increased in respect to the healthy case
        B=B,
        v0=6.0,
        a=aval_mci, # increased in respect to the healthy case. (also remember that TVB uses ms, not s)
        b=b,
        r=0.56,
        nu_max=0.0025, # e0 in the JR original paper
        # TVB factors C_i into J*a_i, e.g. C1 = a_1 * J
        J=135,
        a_1=1.0,
        a_2=0.8,
        a_3= 0.25,
        a_4= 0.25, 
        mu=0.22, # avg of 120 and 320 pulses/s
    )



    # implement JR + afferent PSP
    class JRPSP(tvb.models.JansenRit):
        state_variable_range = Final(
            default={"y0": np.array([-1.0, 1.0]),
                     "y1": np.array([-500.0, 500.0]),
                     "y2": np.array([-50.0, 50.0]),
                     "y3": np.array([-6.0, 6.0]),
                     "y4": np.array([-20.0, 20.0]),
                     "y5": np.array([-500.0, 500.0]),
                     "y6": np.array([-20.0, 20.0]),
                     "y7": np.array([-500.0, 500.0])})

        variables_of_interest = List(
            of=str,
            label="Variables watched by Monitors",
            choices=("y0", "y1", "y2", "y3", "y4", "y5", "y6", "y7"),
            default=("y0", "y1", "y2", "y3"))

        state_variables = tuple('y0 y1 y2 y3 y4 y5 y6 y7'.split())
        _nvar = 8
        cvar = np.array([6], dtype=np.int32)

        def dfun(self, state_variables, coupling, local_coupling=0.0):
            dy = np.zeros((8, state_variables.shape[1], 1))
            # TVB's JR is eq 6 only
            dy[:6] = super().dfun(state_variables[:6], coupling, local_coupling)
            # tack on PSP for efferent following eq 8
            # NB with this, only y12 is coupling var for TVB
            y0, y1, y2, y3, y4, y5, y6, y7 = state_variables
            a_d = self.a / 3.0
            sigm_y1_y2 = 2.0 * self.nu_max / (1.0 + np.exp(self.r * (self.v0 - (y1 - y2))))
            dy[6] = y7
            dy[7] = self.A * a_d * sigm_y1_y2 - 2.0 * a_d * y7 - self.a**2 * y6
            return dy

    # factor out noise from dy4 = A a (p(t) + ...) as y4 += dt (...) + A a dW_t
    # this allows us to model the noise as TVB does it, though scaling requires experiment
    noise_seed= random.randint(1,100)
    nsig = np.zeros((8, 76, 1))
    nsig[4] = model_pars['A'] * model_pars['a'] * (.320 - .120) * 5e-3
    noise = tvb.noise.Additive(nsig=nsig,noise_seed=noise_seed) #

    #setting up monitors:
    mon_tavg = monitors.TemporalAverage(period=1.)
    mon_EEG = monitors.EEG.from_file()
    mon_EEG.period=1. 


    #Bundling
    what_to_watch = (mon_tavg, mon_EEG)

    #Bundling
    what_to_watch = (mon_tavg, mon_EEG)



    nodes = [35, 36,73,74] 
    stim_weights = np.zeros((con.number_of_regions, 1))
    stim_weights[nodes] = np.array([3.5, 0.0,3.5,0.0])[:, np.newaxis]
    eqn_t = equations.PulseTrain()
    eqn_t.parameters["onset"] = 500.0 # ms
    eqn_t.parameters["tau"]   = tau  # ms
    eqn_t.parameters["T"]     = 1500  # 0.002kHz repetition frequency
    eqn_t.parameters["amp"]   = amplitude

    stimulus = patterns.StimuliRegion(temporal = eqn_t,
                                      connectivity = con, 
                                      weight = stim_weights)

    sim = simulator.Simulator(connectivity=con,
                              conduction_speed=np.float(con.speed),
                              model=JRPSP(
                              variables_of_interest=("y0", "y1", "y2", "y3", "y4", "y5", "y6", "y7"),
                              **{k: np.array(v) for k, v in model_pars.items()}),
                              coupling=tvb.coupling.Linear(a=np.r_[aval_mci*10]),
                              integrator=tvb.integrators.EulerStochastic(dt=0.1, noise=noise),
                              #coupling=coupling.SigmoidalJansenRit(a=numpy.array([10.0])),
                              #integrator=integrators.HeunStochastic(dt=2 ** -4, noise=noise.Additive(nsig=sigma)),
                              #monitors=(monitors.TemporalAverage(period=1),), #period in ms
                              monitors=what_to_watch,
                              stimulus = stimulus,
                              simulation_length=1500)
    sim.configure()

    sim_time = 1500
    (ttavg_ad, tavg_ad), (teeg_ad, eeg_ad) = sim.run(simulation_length=sim_time)

    # Discarded last seconds to better show on plot, keeping the whole Time Series for later power spectra analysis 
    tavg_ad_whole = tavg_ad.copy()
    eeg_ad_whole = eeg_ad.copy() 

    tavg_ad_mask = tavg_ad[1000:, :, :, :]
    eeg_ad_mask = eeg_ad[1000:, :, :, :]




    tavg_ad /= (np.max(tavg_ad,0) - np.min(tavg_ad,0 ))
    tavg_ad -= np.mean(tavg_ad, 0)
    eeg_ad /= (np.max(eeg_ad,0) - np.min(eeg_ad,0 ))
    eeg_ad -= np.mean(eeg_ad, 0)

    avg= []
    m_eeg_ad= eeg_ad[:,0,chan,0]
    avg= m_eeg_ad.mean(1)
    
    mask= np.arange(550,600)
    integral= spi.simpson(np.squeeze(avg[mask]),mask)
    
    min_eeg=np.min(np.squeeze(avg[mask]))
    argmin_eeg = np.argmin(np.squeeze(avg[mask]))

    #m_eeg_hc= eeg_hc[:,0,chan,0]
    mon_EEG = monitors.EEG.from_file()

    
    return [round(integral, 4),avg,min_eeg,argmin_eeg,ttavg_ad,tavg_ad[:, 0,35, 0]]

# %%
weightval_mci = 2
aval_mci =0.1112
bval_mci =0.0257

weightval_scd =1
aval_scd = 0.1055
bval_scd = 0.037

weightval =0.815
aval = 0.10119
bval = 0.0456


chan=[8,9,30,32,33]

# %%
save_results_to =  '/home/bbpnrsoa/Tesi/fig/'

# %% [markdown]
# ## VEP SIMULATION PLOT

# %%
output_CTR=[]
avg_CTR=[]

output_SCD=[]
output_MCI=[]

avg_SCD=[]
avg_MCI=[]

# %%
# optimal values for the amplitude 
output_CTR=[]
avg_CTR=[]
amp_CTR=0.22750
amp_SCD= 0.06336
amp_MCI= 0.05368

# %%
for i in  range(0,10):
    
    output_CTR += [myfunct_CTR(chan,amp_CTR, 5)]
    avg_CTR+=[myfunct_CTR(chan,amp_CTR,5)[1]]
# Out:
# 2024-04-02 21:49:10,037 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:49:10,152 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# <ipython-input-2-cace4f07848d>:287: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   conduction_speed=np.float(con.speed),
# <ipython-input-2-cace4f07848d>:245: RuntimeWarning: overflow encountered in exp
#   sigm_y1_y2 = 2.0 * self.nu_max / (1.0 + np.exp(self.r * (self.v0 - (y1 - y2))))
# 2024-04-02 21:49:15,906 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:49:16,022 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:49:21,811 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:49:21,930 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:49:27,601 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:49:27,719 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:49:33,526 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:49:33,644 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:49:39,236 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:49:39,352 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:49:45,082 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:49:45,196 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:49:50,873 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:49:50,988 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:49:56,670 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:49:56,786 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:50:02,485 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:50:02,598 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:50:08,200 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:50:08,316 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:50:14,010 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:50:14,122 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:50:19,834 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:50:19,953 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:50:25,656 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:50:25,771 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:50:31,467 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:50:31,581 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:50:37,253 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:50:37,366 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:50:43,016 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:50:43,133 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:50:48,802 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:50:48,915 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:50:54,619 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:50:54,737 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 21:51:00,518 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 21:51:00,636 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)

# %%
for i in  range(0,80):
    output_SCD += [myfunct_SCD(chan,amp_SCD, 21.7)]
    avg_SCD+=[myfunct_SCD(chan,amp_SCD, 21.7)[1]]
# Out:
# 2024-04-02 14:58:00,943 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:01,059 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# <ipython-input-3-0096203ebad6>:305: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   conduction_speed=np.float(con.speed),
# <ipython-input-3-0096203ebad6>:260: RuntimeWarning: overflow encountered in exp
#   sigm_y1_y2 = 2.0 * self.nu_max / (1.0 + np.exp(self.r * (self.v0 - (y1 - y2))))
# 2024-04-02 14:58:06,305 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:06,419 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:58:11,751 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:11,866 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:58:17,189 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:17,301 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:58:22,659 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:22,773 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:58:28,423 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:28,535 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:58:34,205 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:34,320 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:58:39,784 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:39,897 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:58:45,248 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:45,359 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:58:50,606 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:50,715 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:58:55,999 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:58:56,106 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:01,386 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:01,500 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:06,837 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:06,949 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:12,292 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:12,403 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:17,802 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:17,911 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:23,215 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:23,327 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:28,655 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:28,773 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:34,175 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:34,285 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:39,686 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:39,797 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:45,045 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:45,164 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:50,505 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:50,620 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 14:59:55,893 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 14:59:56,001 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:01,232 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:01,343 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:06,571 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:06,688 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:12,079 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:12,197 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:17,573 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:17,685 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:22,972 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:23,085 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:28,408 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:28,518 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:33,849 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:33,962 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:39,356 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:39,470 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:44,732 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:44,846 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:50,308 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:50,422 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:00:56,164 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:00:56,272 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:01,665 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:01,773 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:07,113 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:07,229 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:12,599 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:12,710 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:18,068 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:18,176 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:23,497 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:23,601 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:28,852 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:28,961 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:34,241 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:34,351 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:39,689 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:39,797 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:45,133 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:45,245 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:50,709 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:50,824 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:01:56,195 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:01:56,305 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:01,702 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:01,816 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:07,246 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:07,362 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:12,683 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:12,797 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:18,164 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:18,272 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:23,617 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:23,730 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:29,095 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:29,212 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:34,572 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:34,685 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:40,137 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:40,249 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:45,603 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:45,718 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:51,080 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:51,194 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:02:56,503 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:02:56,612 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:01,925 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:02,036 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:07,366 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:07,480 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:12,829 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:12,942 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:18,289 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:18,397 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:23,725 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:23,843 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:29,191 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:29,301 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:34,661 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:34,775 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:40,189 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:40,303 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:45,708 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:45,825 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:51,176 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:51,288 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:03:56,651 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:03:56,770 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:02,171 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:02,287 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:07,638 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:07,752 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:13,085 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:13,197 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:18,492 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:18,600 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:23,875 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:23,986 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:29,391 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:29,504 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:34,804 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:34,917 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:40,163 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:40,276 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:45,552 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:45,659 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:50,900 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:51,015 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:04:56,332 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:04:56,439 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:01,785 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:01,905 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:07,216 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:07,327 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:12,758 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:12,869 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:18,236 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:18,353 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:23,644 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:23,751 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:28,985 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:29,102 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:34,353 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:34,466 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:39,748 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:39,859 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:45,118 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:45,231 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:50,512 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:50,620 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:05:55,930 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:05:56,041 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:01,292 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:01,406 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:06,794 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:06,909 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:12,240 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:12,351 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:17,981 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:18,096 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:23,514 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:23,628 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:28,970 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:29,081 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:34,448 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:34,559 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:39,987 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:40,098 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:45,414 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:45,525 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:50,860 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:50,974 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:06:56,298 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:06:56,408 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:01,722 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:01,832 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:07,168 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:07,279 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:12,689 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:12,805 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:18,128 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:18,238 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:23,523 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:23,638 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:29,052 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:29,161 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:34,537 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:34,647 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:40,022 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:40,131 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:45,378 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:45,496 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:50,756 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:50,867 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:07:56,199 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:07:56,318 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:01,665 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:01,781 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:07,173 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:07,286 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:13,027 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:13,139 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:18,504 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:18,613 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:23,953 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:24,061 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:29,522 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:29,636 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:34,945 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:35,060 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:40,540 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:40,656 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:46,093 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:46,203 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:51,522 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:51,635 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:08:57,194 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:08:57,309 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:02,966 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:03,088 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:08,437 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:08,549 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:13,948 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:14,061 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:19,449 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:19,561 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:24,981 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:25,099 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:30,480 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:30,598 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:35,954 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:36,069 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:41,452 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:41,564 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:46,880 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:46,993 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:52,297 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:52,414 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:09:57,781 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:09:57,900 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:03,266 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:03,381 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:08,670 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:08,781 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:14,125 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:14,233 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:19,604 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:19,724 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:25,177 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:25,292 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:30,637 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:30,750 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:36,141 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:36,253 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:41,691 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:41,803 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:47,173 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:47,286 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:52,657 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:52,771 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:10:58,202 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:10:58,311 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:03,662 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:03,776 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:09,145 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:09,257 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:14,593 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:14,704 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:20,217 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:20,330 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:26,201 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:26,314 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:32,141 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:32,252 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:37,920 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:38,035 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:43,352 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:43,462 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:48,655 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:48,764 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:54,036 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:54,148 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:11:59,461 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:11:59,573 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:12:04,894 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:12:05,001 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:12:10,483 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:12:10,593 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:12:15,969 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:12:16,082 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:12:21,523 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:12:21,633 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:12:27,225 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:12:27,335 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:12:32,687 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:12:32,796 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)

# %%
for i in  range(0,40):
    output_MCI += [myfunct_MCI(chan,amp_MCI, 21.7)]
    avg_MCI+=[myfunct_MCI(chan,amp_MCI, 21.7)[1]]
# Out:
# 2024-04-02 15:12:38,131 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:12:38,248 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# <ipython-input-4-94f437550f56>:301: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   conduction_speed=np.float(con.speed),
# <ipython-input-4-94f437550f56>:261: RuntimeWarning: overflow encountered in exp
#   sigm_y1_y2 = 2.0 * self.nu_max / (1.0 + np.exp(self.r * (self.v0 - (y1 - y2))))
# 2024-04-02 15:12:43,565 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:12:43,686 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:12:48,992 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:12:49,108 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:12:54,437 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:12:54,549 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:12:59,938 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:00,051 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:05,429 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:05,545 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:11,263 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:11,375 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:16,882 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:16,996 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:22,253 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:22,364 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:27,551 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:27,667 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:32,878 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:32,988 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:38,220 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:38,329 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:43,577 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:43,688 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:49,009 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:49,123 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:54,424 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:54,536 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:13:59,851 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:13:59,967 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:05,316 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:05,429 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:10,713 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:10,830 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:16,230 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:16,342 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:21,809 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:21,921 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:27,134 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:27,244 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:32,410 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:32,519 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:37,823 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:37,939 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:43,245 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:43,358 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:48,547 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:48,658 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:53,855 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:53,969 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:14:59,150 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:14:59,262 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:04,477 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:04,589 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:09,804 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:09,913 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:15,125 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:15,236 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:20,415 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:20,524 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:25,729 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:25,839 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:30,997 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:31,107 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:36,312 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:36,425 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:41,595 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:41,705 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:46,923 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:47,033 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:52,164 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:52,274 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:15:57,432 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:15:57,546 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:02,671 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:02,781 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:07,960 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:08,072 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:13,557 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:13,668 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:18,846 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:18,953 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:24,193 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:24,302 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:29,598 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:29,704 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:35,023 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:35,138 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:40,576 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:40,686 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:45,972 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:46,083 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:51,409 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:51,515 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:16:56,781 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:16:56,893 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:02,195 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:02,302 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:07,563 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:07,668 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:12,919 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:13,029 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:18,225 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:18,335 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:23,565 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:23,676 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:28,942 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:29,049 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:34,379 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:34,489 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:39,768 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:39,877 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:45,093 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:45,200 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:50,392 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:50,501 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:17:55,667 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:17:55,780 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:00,939 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:01,050 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:06,536 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:06,644 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:12,024 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:12,136 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:17,410 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:17,522 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:22,783 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:22,900 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:28,147 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:28,262 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:33,551 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:33,663 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:39,042 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:39,160 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:44,504 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:44,617 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:49,939 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:50,050 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:18:55,375 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:18:55,494 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:19:00,760 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:19:00,872 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:19:06,150 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:19:06,261 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:19:11,528 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:19:11,646 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:19:17,085 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:19:17,195 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:19:22,776 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:19:22,892 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:19:28,194 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:19:28,308 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:19:33,619 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:19:33,732 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:19:39,073 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:19:39,188 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)
# 2024-04-02 15:19:44,472 - WARNING - tvb.basic.readers - File 'hemispheres' not found in ZIP.
# 2024-04-02 15:19:44,589 - INFO - tvb.simulator.monitors - Projection configured gain shape (65, 76)

# %%
avg_output_CTR= np.asarray(output_CTR).mean(0)
avg_output_SCD= np.asarray(output_SCD).mean(0)
avg_output_MCI= np.asarray(output_MCI).mean(0)
# Out:
# <ipython-input-39-2bf637172715>:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   avg_output_CTR= np.asarray(output_CTR).mean(0)
# <ipython-input-39-2bf637172715>:2: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   avg_output_SCD= np.asarray(output_SCD).mean(0)
# <ipython-input-39-2bf637172715>:3: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   avg_output_MCI= np.asarray(output_MCI).mean(0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle

times = np.linspace(200, 1500, 666)

with open('./ERP_MICHELA.pkl', 'rb') as file:
       ERP = pickle.load(file)

# %%
def parameters(mat):
    mask=np.logical_and(times>200, times<400)

    integral= spi.simpson(mat[mask],times[mask])
    min_=np.min(np.squeeze(mat[mask]))
    min_time= times[mask][np.argmin(mat[mask])]
 
    
    return[integral,min_, min_time]


res_CTR=parameters(np.mean(ERP['CTR'], axis=0))
res_SCD=parameters(np.mean(ERP['SCD'], axis=0))
res_MCI=parameters(np.mean(ERP['MCI'], axis=0))

# %%
def mse(actual, predicted):
    return np.square(np.subtract(np.array(actual), np.array(predicted))).mean(0)


mse_CTR = mse(((np.asarray(avg_CTR))*100),(avg_output_CTR[1])*100)
mse_SCD=  mse((np.asarray(avg_SCD))*100,(avg_output_SCD[1])*100)
mse_MCI = mse((np.asarray(avg_MCI))*100,(avg_output_MCI[1])*100)


mse_CTRt = mse(ERP['CTR'].min(1),res_CTR[1])
mse_SCDt =  mse(ERP['SCD'].min(1),res_SCD[1])
mse_MCIt = mse(ERP['MCI'].min(1),res_MCI[1])

# %%
mon_EEG = monitors.EEG.from_file()
fig,ax= plt.subplots(1,2,figsize=(34,13),sharey=True,sharex=True)
fig.tight_layout()
ax=ax.flatten()
mask= np.logical_and(times>415, times<=700)

#fig.savefig(save_results_to + 'fig1.pdf')
ax[1].plot(avg_output_MCI[4], avg_output_MCI[1]*100, color="r", label="MCI case")
ax[1].plot(avg_output_SCD[4],avg_output_SCD[1]*100, color="g", label="SCD case")
ax[1].plot( avg_output_CTR[4], avg_output_CTR[1]*100, color="b", label="CTR case")
ax[1].set_xticklabels(['0', '25', '50' , '75' , '100', ' 125', '150' , '175', '200'])

ax[1].errorbar(avg_output_MCI[4], avg_output_MCI[1]*100,mse_MCI/15, color="r", alpha=0.2,linewidth=5)
ax[1].errorbar(avg_output_SCD[4],avg_output_SCD[1]*100,mse_SCD/10, color="g", alpha=0.2,linewidth=5 )
ax[1].errorbar(avg_output_CTR[4], avg_output_CTR[1]*100,mse_CTR/10, color="b",  alpha=0.2,linewidth=5)

#ax[1].axvline(x=500)
#ax[1].axvline(x=700)

ax[1].legend(loc="lower right", title="Legend", frameon=False,fontsize=32,title_fontsize=32)
ax[1].set_xlabel('Time [ms]',fontsize=35)

ax[1].set_title('b) Simulated EEG output',fontsize=40)
ax[1].set_xlim(415,710)
ax[1].tick_params(axis='x', labelsize=32)
ax[1].tick_params(axis='y', labelsize=32)

ax[1].set_ylim(-7,5)
ax[0].plot(times[mask], np.mean(ERP['CTR'], axis=0)[mask], 'b', alpha=1, linewidth=7)
ax[0].plot(times[mask], np.mean(ERP['SCD'], axis=0)[mask], 'g', alpha=1, linewidth=7)
ax[0].plot(times[mask], np.mean(ERP['MCI'], axis=0)[mask], 'r', alpha=1, linewidth=7)
ax[0].set_xticklabels(['0', '25', '50' , '75' , '100', ' 125', '150' , '175', '200'])


ax[0].errorbar(times[mask], np.mean(ERP['CTR'], axis=0)[mask], mse_CTRt/115, color="b", alpha=0.2,linewidth=10)
ax[0].errorbar(times[mask], np.mean(ERP['SCD'], axis=0)[mask],mse_SCDt/110, color="g", alpha=0.2,linewidth=10 )
ax[0].errorbar(times[mask], np.mean(ERP['MCI'], axis=0)[mask],mse_MCIt/110, color="r",  alpha=0.2,linewidth=10)


ax[0].set_title('a) Empirical EEG output',fontsize=40)
ax[0].set_xlabel('Time [ms]',fontsize=35)
ax[0].set_ylabel('[μV]',fontsize=35)
ax[0].tick_params(axis='x', labelsize=32)
ax[0].tick_params(axis='y', labelsize=32)

fig.savefig(save_results_to +'eeg3.png')
# Out:
# <ipython-input-43-c691bcb77508>:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels(['0', '25', '50' , '75' , '100', ' 125', '150' , '175', '200'])
# <ipython-input-43-c691bcb77508>:32: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(['0', '25', '50' , '75' , '100', ' 125', '150' , '175', '200'])

# %%
import pickle

# create a Python object
noisy = {'HC': avg_output_CTR[1] , 'SCD': avg_output_SCD[1],'MCI': avg_output_MCI[1] }

# save the object to a .pkl file
with open('noisy.pkl', 'wb') as f:
    pickle.dump(noisy, f)
